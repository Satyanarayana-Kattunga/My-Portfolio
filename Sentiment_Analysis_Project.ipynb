# %% [markdown]
# <a href="https://colab.research.google.com/github/Satyanarayana-Kattunga/My-Portfolio/blob/main/Sentiment_Analysis_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import zipfile
import os

zip_path = '/content/sentiment_analysis_project.zip'
extract_path = '/content/'

with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(extract_path)

print("Project Extracted Successfully")
# Out:
# Project Extracted Successfully

# %%
import os

project_path = '/content/sentiment_analysis_project'

for root, dirs, files in os.walk(project_path):
    print(root)
# Out:
# /content/sentiment_analysis_project
# /content/sentiment_analysis_project/sentiment_project
# /content/sentiment_analysis_project/sentiment_project/documentation
# /content/sentiment_analysis_project/sentiment_project/dataset
# /content/sentiment_analysis_project/sentiment_project/outputs
# /content/sentiment_analysis_project/sentiment_project/outputs/plots
# /content/sentiment_analysis_project/sentiment_project/scripts
# /content/sentiment_analysis_project/sentiment_project/{dataset,scripts,dashboard,documentation,outputs}
# /content/sentiment_analysis_project/sentiment_project/dashboard

# %%
# !pip install pandas numpy matplotlib seaborn scikit-learn nltk wordcloud openpyxl

# %%
# %cd /content/sentiment_analysis_project/sentiment_project
# Out:
# /content/sentiment_analysis_project/sentiment_project

# %%
# !python scripts/sentiment_analysis.py
# Out:
# ...
#   SOCIAL MEDIA SENTIMENT ANALYSIS — ML PIPELINE
# ...
#
# 📊 Dataset shape : (3000, 15)
#    Columns       : ['tweet_id', 'date', 'platform', 'brand', 'text', 'sentiment', 'sentiment_score', 'likes', 'retweets', 'replies', 'followers', 'location', 'device', 'verified', 'engagement_rate']
#
# sentiment
# Positive    1331
# Negative     897
# Neutral      772
# Name: count, dtype: int64
#
# 🧹 Cleaning text...
# ⚙️  Building TF-IDF features...
#    Train: 2400 | Test: 600
#
# 🤖 Training models...
#
#   ✅ Logistic Regression        Accuracy: 1.0000  |  CV: 1.0000
#   ✅ Naive Bayes                Accuracy: 1.0000  |  CV: 1.0000
#   ✅ Random Forest              Accuracy: 1.0000  |  CV: 1.0000
#
# 🏆 Best model: Logistic Regression (1.0000)
#
# 📋 Classification Report (Logistic Regression):
#               precision    recall  f1-score   support
#
#     Negative       1.00      1.00      1.00       180
#      Neutral       1.00      1.00      1.00       154
# ...

# %%
from IPython.display import Image, display

image_path = '/content/sentiment_analysis_project/sentiment_project/outputs/plots/01_sentiment_distribution.png'

display(Image(filename=image_path))

# %%
# !python scripts/predict.py
# Out:
# ...
#   SENTIMENT PREDICTION RESULTS
# ...
#
# 🟢 [Positive]
#    Tweet: Just got the new Apple iPhone and it's absolutely incredible! Best phone ev...
#    Confidence: {'Negative': np.float64(2.2), 'Neutral': np.float64(2.8), 'Positive': np.float64(95.0)}
#
# 🟢 [Positive]
#    Tweet: Amazon delivery was late again and customer service refused to help. Never ...
#    Confidence: {'Negative': np.float64(40.8), 'Neutral': np.float64(5.5), 'Positive': np.float64(53.7)}
#
# 🟡 [Neutral]
#    Tweet: Samsung announced a new product today. Might check it out when reviews come...
#    Confidence: {'Negative': np.float64(5.8), 'Neutral': np.float64(84.3), 'Positive': np.float64(9.9)}
#
# 🔴 [Negative]
#    Tweet: Nike shoes quality has really gone downhill recently. Very disappointed 👎
#    Confidence: {'Negative': np.float64(85.4), 'Neutral': np.float64(7.3), 'Positive': np.float64(7.3)}
#
# 🟢 [Positive]
#    Tweet: Netflix added some great new shows this month. Really enjoying the new cont...
# ...
